# %%
import os
import pandas as pd
import numpy as np

path = './data/'
data = pd.read_csv(os.path.join(path, 'xgolf_contents_final.csv'), encoding='utf-8', index_col=0)

data # 데이터 확인
# Out:
#        golf_name                     title          id          datetime  \
# 1             금강                      굿 금강     yun****  2022.07.23 11:13
# 2      비에이비스타퍼블릭  양프로,티칭프로테스트를 앞둔 예비프로와 함께   Wls******  2022.07.23 11:08
# 3            몽베르                 경기북부의 몽베르  NV2*******  2022.07.23 10:04
# 4          스카이밸리     재촉만 하지 않았으면 최고였을텐데...      bab***  2022.07.22 23:11
# 5            몽베르                  몽베르라운딩후기   ljk******  2022.07.22 11:25
# ...          ...                       ...         ...               ...
# 47860         기흥                좋은골프장 좋은그린   NV5******  2018.01.01 18:46
# 47861       아일랜드                    아일랜드CC     dda****  2018.01.01 14:58
# 47862         기흥                     눈 속에서      l3l***  2018.01.01 12:13
# 47863         88             2017년 마지막 라운딩  pol*******  2018.01.01 04:17
# 47864        남서울                 눈은 왔었지만,,      msd***  2018.01.01 00:39
#
#        year  month  day   time  golfscore  caddiescore  coursescore  \
# 1      2022      7   23  11:13       10.0           10           10
# 2      2022      7   23  11:08       10.0           10           10
# 3      2022      7   23  10:04       10.0           10           10
# 4      2022      7   22  23:11       10.0           10           10
# 5      2022      7   22  11:25       10.0           10           10
# ...     ...    ...  ...    ...        ...          ...          ...
# 47860  2018      1    1  18:46       10.0           10           10
# 47861  2018      1    1  14:58       10.0           10           10
# 47862  2018      1    1  12:13        9.5           10           10
# 47863  2018      1    1  04:17        9.0            8            8
# 47864  2018      1    1  00:39       10.0           10           10
#
#        pricescore  facility                                           contents
# 1              10        10                                   페어웨이 그린 베스트 명품구장
# 2              10        10  라운딩 체험으로 운동했는데 날씨도 햇빛 없는 날과함께 즐거웠습니다\n모든 좋았으나한...
# 3              10        10                          편안하고 관리가 잘된 골프코스에서 라운딩했네요
# 4              10        10  아침부터 비가 온 것을 제외하고는 좋았습니다.\n잘 관리된 페어웨이와 그린 그리고 ...
# 5              10        10  첫홀은 비가와서 징행할까 말까 했었는데\n그래도 멀리왔는데 치고가자 고 일행이 적극...
# ...           ...       ...                                                ...
# 47860          10        10                         겨울에도 기흥은 그린이 좋아요.속도도 맘에듭니다
# 47861          10        10                         바람이 좀 춥긴했지만 관리도 잘되있고 좋았습니다
# 47862           8        10  눈이 오는 바람에 정상적인 라운드를 할 수 없었지만 너무 좋은 멤버들과 캐디 덕분에...
# 47863          10        10  다행히 날씨가 춥지 않아 즐거운 라운딩이었음.\n11:32 티업. 전반 지나고 그늘...
# 47864          10        10               잼있는 코스와 친절한 캐디분이 있어서 항상 줄거운 골프장이네요^^
#
# [47828 rows x 14 columns]

# %%
data.info() # 개괄 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47828 entries, 1 to 47864
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   golf_name    47828 non-null  object
#  1   title        47828 non-null  object
#  2   id           47828 non-null  object
#  3   datetime     47828 non-null  object
#  4   year         47828 non-null  int64
#  5   month        47828 non-null  int64
#  6   day          47828 non-null  int64
#  7   time         47828 non-null  object
#  8   golfscore    47828 non-null  float64
#  9   caddiescore  47828 non-null  int64
#  10  coursescore  47828 non-null  int64
#  11  pricescore   47828 non-null  int64
#  12  facility     47828 non-null  int64
#  13  contents     47828 non-null  object
# dtypes: float64(1), int64(7), object(6)
# memory usage: 5.5+ MB

# %% [markdown]
# ### 데이터 전처리

# %%
# 중복 행 확인
data[(data.duplicated())]
# Out:
#       golf_name          title            id          datetime  year  month  \
# 82          그린힐  최고의 캐디분을 만난 날    don*******  2022.07.04 12:26  2022      7
# 303         샴발라           중간이상        kaa***  2022.05.26 09:15  2022      5
# 1422       서원힐스           겨울골프       kin****  2022.02.04 09:44  2022      2
# 2385      스카이밸리             ？？        yh0***  2021.09.12 11:05  2021      9
# 3091      강남300         다 좋았네요  KK1*********  2021.07.31 13:59  2021      7
# ...         ...            ...           ...               ...   ...    ...
# 47860        기흥     좋은골프장 좋은그린     NV5******  2018.01.01 18:46  2018      1
# 47861      아일랜드         아일랜드CC       dda****  2018.01.01 14:58  2018      1
# 47862        기흥          눈 속에서        l3l***  2018.01.01 12:13  2018      1
# 47863        88  2017년 마지막 라운딩    pol*******  2018.01.01 04:17  2018      1
# 47864       남서울      눈은 왔었지만,,        msd***  2018.01.01 00:39  2018      1
#
#        day   time  golfscore  caddiescore  coursescore  pricescore  facility  \
# 82       4  12:26        8.5           10            8          10         6
# 303     26  09:15        6.5           10            8           4         4
# 1422     4  09:44        9.0           10           10           8         8
# 2385    12  11:05        9.5           10            8          10        10
# 3091    31  13:59       10.0           10           10          10        10
# ...    ...    ...        ...          ...          ...         ...       ...
# 47860    1  18:46       10.0           10           10          10        10
# 47861    1  14:58       10.0           10           10          10        10
# 47862    1  12:13        9.5           10           10           8        10
# 47863    1  04:17        9.0            8            8          10        10
# 47864    1  00:39       10.0           10           10          10        10
#
#                                                 contents
# 82     폭염으로 아주 힘든 라운딩였지만 그래도 캐디님의 밝은 웃음과 성실한 태도에 정말 감...
# 303                                      코스가 어렵지만 재미있었어요
# 1422   올해 첫 라운딩. 부킹할 때만해도 조금은 덜 추우리라 예상했지만 역시 겨울은 겨울....
# 2385                          코스 관리 최고 그린 관리가 조금 아쉽네요 ??
# 3091                                  가격대비 관리도 잘 되어있고 ??
# ...                                                  ...
# 47860                         겨울에도 기흥은 그린이 좋아요.속도도 맘에듭니다
# 47861                         바람이 좀 춥긴했지만 관리도 잘되있고 좋았습니다
# 47862  눈이 오는 바람에 정상적인 라운드를 할 수 없었지만 너무 좋은 멤버들과 캐디 덕분에...
# 47863  다행히 날씨가 춥지 않아 즐거운 라운딩이었음.\n11:32 티업. 전반 지나고 그늘...
# 47864               잼있는 코스와 친절한 캐디분이 있어서 항상 줄거운 골프장이네요^^
#
# [18073 rows x 14 columns]

# %%
# 중복 행 (18073) 제거
data = data.drop_duplicates()
data
# Out:
#        golf_name                     title          id          datetime  \
# 1             금강                      굿 금강     yun****  2022.07.23 11:13
# 2      비에이비스타퍼블릭  양프로,티칭프로테스트를 앞둔 예비프로와 함께   Wls******  2022.07.23 11:08
# 3            몽베르                 경기북부의 몽베르  NV2*******  2022.07.23 10:04
# 4          스카이밸리     재촉만 하지 않았으면 최고였을텐데...      bab***  2022.07.22 23:11
# 5            몽베르                  몽베르라운딩후기   ljk******  2022.07.22 11:25
# ...          ...                       ...         ...               ...
# 38084         기흥                좋은골프장 좋은그린   NV5******  2018.01.01 18:46
# 38085       아일랜드                    아일랜드CC     dda****  2018.01.01 14:58
# 38086         기흥                     눈 속에서      l3l***  2018.01.01 12:13
# 38087         88             2017년 마지막 라운딩  pol*******  2018.01.01 04:17
# 38088        남서울                 눈은 왔었지만,,      msd***  2018.01.01 00:39
#
#        year  month  day   time  golfscore  caddiescore  coursescore  \
# 1      2022      7   23  11:13       10.0           10           10
# 2      2022      7   23  11:08       10.0           10           10
# 3      2022      7   23  10:04       10.0           10           10
# 4      2022      7   22  23:11       10.0           10           10
# 5      2022      7   22  11:25       10.0           10           10
# ...     ...    ...  ...    ...        ...          ...          ...
# 38084  2018      1    1  18:46       10.0           10           10
# 38085  2018      1    1  14:58       10.0           10           10
# 38086  2018      1    1  12:13        9.5           10           10
# 38087  2018      1    1  04:17        9.0            8            8
# 38088  2018      1    1  00:39       10.0           10           10
#
#        pricescore  facility                                           contents
# 1              10        10                                   페어웨이 그린 베스트 명품구장
# 2              10        10  라운딩 체험으로 운동했는데 날씨도 햇빛 없는 날과함께 즐거웠습니다\n모든 좋았으나한...
# 3              10        10                          편안하고 관리가 잘된 골프코스에서 라운딩했네요
# 4              10        10  아침부터 비가 온 것을 제외하고는 좋았습니다.\n잘 관리된 페어웨이와 그린 그리고 ...
# 5              10        10  첫홀은 비가와서 징행할까 말까 했었는데\n그래도 멀리왔는데 치고가자 고 일행이 적극...
# ...           ...       ...                                                ...
# 38084          10        10                         겨울에도 기흥은 그린이 좋아요.속도도 맘에듭니다
# 38085          10        10                         바람이 좀 춥긴했지만 관리도 잘되있고 좋았습니다
# 38086           8        10  눈이 오는 바람에 정상적인 라운드를 할 수 없었지만 너무 좋은 멤버들과 캐디 덕분에...
# 38087          10        10  다행히 날씨가 춥지 않아 즐거운 라운딩이었음.\n11:32 티업. 전반 지나고 그늘...
# 38088          10        10               잼있는 코스와 친절한 캐디분이 있어서 항상 줄거운 골프장이네요^^
#
# [29755 rows x 14 columns]

# %%
# 같은 아이디로 같은 제목과 내용의 글을 올린 경우 있는지 확인
data_dup = data[(data.duplicated(['id', 'title', 'contents']))]
data_dup
# Out:
#          golf_name            title          id          datetime  year  \
# 81             그린힐    최고의 캐디분을 만난 날  don*******  2022.07.04 12:26  2022
# 7245        레이크사이드              좋아요    kei*****  2020.10.04 11:22  2020
# 15928           자유          자유cc 후기     khl****  2019.03.07 21:12  2019
# 16035  레이크힐스안성(P9)             가성비굿    kks*****  2019.03.03 20:28  2019
# 16772           88               88    act*****  2018.12.17 15:07  2018
# ...            ...              ...         ...               ...   ...
# 37022         아일랜드             잘치고ㅡ     lhy****  2018.03.06 11:11  2018
# 37216         블루헤런    블루헤런을 다녀와서~^^       oza**  2018.03.02 11:11  2018
# 37266        써닝포인트           최악이었네요  NV4*******  2018.03.01 10:06  2018
# 37276          남서울  코스관리 잘 되어있는 골프장      plo***  2018.02.28 22:25  2018
# 37487         아시아나           최고 스코어      sai***  2018.02.22 10:05  2018
#
#        month  day   time  golfscore  caddiescore  coursescore  pricescore  \
# 81         7    4  12:26        8.5           10            8          10
# 7245      10    4  11:22       10.0           10           10          10
# 15928      3    7  21:12        9.0           10            8          10
# 16035      3    3  20:28       10.0           10           10          10
# 16772     12   17  15:07       10.0           10           10          10
# ...      ...  ...    ...        ...          ...          ...         ...
# 37022      3    6  11:11       10.0           10           10          10
# 37216      3    2  11:11       10.0           10           10          10
# 37266      3    1  10:06        7.5            8            6           8
# 37276      2   28  22:25       10.0           10           10          10
# 37487      2   22  10:05       10.0           10           10          10
#
#        facility                                           contents
# 81            6  폭염으로 아주 힘든 라운딩였지만 그래도 캐디님의 밝은 웃음과 성실한 태도에 정말 감...
# 7245         10                                        역시 레이크사이드♥?
# 15928         8  평일오후 선결제로 저렴하게 다녀왔어요.\n겨울이 끝나가는데 날씨도 좋고 밀리지도 않...
# 16035        10                                        가격대비 아주좋습니다
# 16772        10                                        너무 좋아요 최고에요
# ...         ...                                                ...
# 37022        10                    날씨도넘좋았고ㅡ동반자들도좋아했다ㅡ\n나중에또오고십다는말을
# 37216        10                   가성비날씨그리고 캐디까지 친절해서 즐거운 롼딩이였네요 ^^
# 37266         8  캐디가 착해서 그냥 재밌게치고 오자했지만\n시작부터 티업시간도 되지 않았는데 짜증나...
# 37276        10                                  캐디도 좋았고 코스도 좋았습니딘
# 37487        10                            요 글래 나간 골프장 중 최고 스코어 80
#
# [103 rows x 14 columns]

# %%
# 위 경우 (103) 리뷰 신뢰도가 낮을것으로 판단 => 삭제
data = data.drop_duplicates(['id', 'title', 'contents'])
data.shape
# Out:
# (29652, 14)

# %%
# 중복 행 확인
data[(data.duplicated())]
# Out:
# Empty DataFrame
# Columns: [golf_name, title, id, datetime, year, month, day, time, golfscore, caddiescore, coursescore, pricescore, facility, contents]
# Index: []

# %%
data['id'].nunique() # unique id 개수 확인
# Out:
# 6134

# %%
data['id'].value_counts() # id별 리뷰 개수 확인(소셜로그인 계정 - NV: Naver, KK: Kakao)
# Out:
# NV2*******      889
# KK1*********    808
# NV3*******      685
# NV1*******      549
# NV4*******      479
#                ...
# aeb*****          1
# fel*****          1
# wid*****          1
# wjc*              1
# ybe***            1
# Name: id, Length: 6134, dtype: int64

# %%
# 네이버 계정 사용 리뷰 확인
data[data['id'].str.contains("NV", case=True)]
# Out:
#       golf_name        title           id          datetime  year  month  day  \
# 3           몽베르    경기북부의 몽베르   NV2*******  2022.07.23 10:04  2022      7   23
# 15          서서울    언제나좋은 서서울   NV4*******  2022.07.20 11:19  2022      7   20
# 19       크리스탈밸리       칭찬합니다.   NV9*******  2022.07.19 15:43  2022      7   19
# 22         360도            귿   NV5*******  2022.07.18 11:10  2022      7   18
# 23          서서울        서서울cc   NV1*******  2022.07.18 11:08  2022      7   18
# ...         ...          ...          ...               ...   ...    ...  ...
# 38056    레이크사이드      겨울 추운 날  NV_********  2018.01.03 16:38  2018      1    3
# 38057        기흥      기흥cc 후기   NV2*******  2018.01.03 15:28  2018      1    3
# 38082       솔모로  2017마지막 라운딩   NV2*******  2018.01.01 21:20  2018      1    1
# 38083       은화삼    겨울골프 중 최고    NV8******  2018.01.01 20:24  2018      1    1
# 38084        기흥   좋은골프장 좋은그린    NV5******  2018.01.01 18:46  2018      1    1
#
#         time  golfscore  caddiescore  coursescore  pricescore  facility  \
# 3      10:04       10.0           10           10          10        10
# 15     11:19        9.5           10           10          10         8
# 19     15:43        8.5           10            8           8         8
# 22     11:10       10.0           10           10          10        10
# 23     11:08        7.5            6           10           8         6
# ...      ...        ...          ...          ...         ...       ...
# 38056  16:38        9.0            6           10          10        10
# 38057  15:28        8.0            8            8           8         8
# 38082  21:20       10.0           10           10          10        10
# 38083  20:24       10.0           10           10          10        10
# 38084  18:46       10.0           10           10          10        10
#
#                                                 contents
# 3                              편안하고 관리가 잘된 골프코스에서 라운딩했네요
# 15                                 음식가격비싼거만빼면 너무좋은 코스관리등
# 19             더운 날씨\n짜증 한 번 없이 열심히 해 준\n캐디 ?혜원 양 칭찬합니다.
# 22                                        귿 또 방문할 예정입니다!
# 23     그린피가 비싼만큼 코스관리는 훌륭했습니다\n다만 캐디님이 신입이셔서.... 캐디피가...
# ...                                                  ...
# 38056                        코스는 얼었어도 재미있음 영상기온을 기다리며~~~
# 38057  12월 30일에 갔는데 날씨도 따뜻해서 좋았습니다\n그린이 얼어서 볼이 튀기도 하고...
# 38082  12/29일 진행한 2인 라운딩\n그주에 가장 따뜻한 하루여서 아주아주 행복하게 게...
# 38083                                 최고의 날씨에서 즐거운 란딩했어요
# 38084                         겨울에도 기흥은 그린이 좋아요.속도도 맘에듭니다
#
# [4010 rows x 14 columns]

# %%
# 카카오 계정 사용 리뷰 확인
data[data['id'].str.contains("KK", case=True)]
# Out:
#        golf_name                 title            id          datetime  year  \
# 8             이포              이포CC 좋아요  KK2*********  2022.07.21 13:06  2022
# 17     포레스트힐(P6)           연습 겸 2인 라운딩  KK1*********  2022.07.19 15:57  2022
# 26            중부        필드는 명문, 캐디는 최악  KK1*********  2022.07.18 07:24  2022
# 27            이포                 최악 이포  KK1*********  2022.07.17 14:36  2022
# 29          해솔리아                     굿  KK2*********  2022.07.17 11:21  2022
# ...          ...                   ...           ...               ...   ...
# 10263       한림광릉                   굿..  KK1*********  2020.04.16 11:27  2020
# 10612     크리스탈밸리  날씨도 좋고 기분좋게 다녀왓어요~!!  KK1*********  2020.03.24 18:25  2020
# 11310       서원힐스       서원 야간 다녀왔습니다~^^  KK1*********  2019.11.21 00:00  2019
# 13244       서원힐스         골뱅이 무침이 짱이에요~  KK1*********  2019.07.11 00:00  2019
# 13528       서원힐스         서원힐스 즐거운 라운딩~  KK1*********  2019.06.30 00:00  2019
#
#        month  day   time  golfscore  caddiescore  coursescore  pricescore  \
# 8          7   21  13:06       10.0           10           10          10
# 17         7   19  15:57       10.0           10           10          10
# 26         7   18  07:24        8.0            2           10          10
# 27         7   17  14:36        4.0            2            8           4
# 29         7   17  11:21       10.0           10           10          10
# ...      ...  ...    ...        ...          ...          ...         ...
# 10263      4   16  11:27       10.0           10           10          10
# 10612      3   24  18:25        8.5            8            8           8
# 11310     11   21  00:00        9.0            8           10           8
# 13244      7   11  00:00        9.5            8           10          10
# 13528      6   30  00:00       10.0           10           10          10
#
#        facility                                           contents
# 8            10                    아늑하고 편안한 라운딩 되었어요\n\n재방문 의사 있어요
# 17           10              노캐디\n연습 2인 라운딩 잘 다녀왔습니다\n가깝고 저렴하고 좋아요
# 26           10  역시나 필드 관리나 클럽하우스 시설은 최고로 좋았지만..\n캐디 때문에 완전 기분 ...
# 27            2  장점 : 근거리, 넓은 페어웨이, 잔디 상태\n단점 : 최악 캐디(고령, 불친절, ...
# 29           10                       인터넷 이용자 댓글보고 기대도 안했는데 아두 만족함
# ...         ...                                                ...
# 10263        10               부킹을쉽게할수있어서조앗구\n시설두아주깔끔하구잔디상태완전조앗습니다.
# 10612        10  크리스탈밸리 너무 기분좋게 다녀왔어요ㅎㅎ\n날씨도 좋고 클럽하우스 음식도 너무 맛있...
# 11310        10           야간 라운딩 했어요~\n날씨도 좋고 코스도 좋고 즐거운 란딩했습니다~
# 13244        10    그늘집에서 골뱅이 무침이랑 막걸리 한잔하면 크~ 홀인원 할수있을 정도로 최곱니다 ㅎㅎ
# 13528        10  서원힐스 처음 내장해서 플레이 했는데\n 그린 상태가 너무 최고고 \n 직원들도 너...
#
# [848 rows x 14 columns]

# %%
# 소셜로그인 계정 (4010 + 848) 리뷰 삭제(과도한 중복 피하기) => 행 개수: 29652 - (4010 + 848) = 24794
data = data[~((data['id'].str.contains('NV', case=True)) | (data['id'].str.contains('KK', case=True)))]
data.shape
# Out:
# (24794, 14)

# %%
data[(data.duplicated())]
# Out:
# Empty DataFrame
# Columns: [golf_name, title, id, datetime, year, month, day, time, golfscore, caddiescore, coursescore, pricescore, facility, contents]
# Index: []

# %% [markdown]
# ## 데이터테이블 생성

# %% [markdown]
# ### 베이스

# %%
# Base DF 생성
data.rename(columns={'golf_name':'cc_name', 'golfscore':'cc_score', 'caddiescore':'caddie', 'coursescore':'course', 'pricescore': 'price'}, inplace=True)
print(data.shape)
data.head()
# Out:
# (24794, 14)
#      cc_name                     title         id          datetime  year  \
# 1         금강                      굿 금강    yun****  2022.07.23 11:13  2022
# 2  비에이비스타퍼블릭  양프로,티칭프로테스트를 앞둔 예비프로와 함께  Wls******  2022.07.23 11:08  2022
# 4      스카이밸리     재촉만 하지 않았으면 최고였을텐데...     bab***  2022.07.22 23:11  2022
# 5        몽베르                  몽베르라운딩후기  ljk******  2022.07.22 11:25  2022
# 6         썬힐             정말 해도해도 너무하네요   cli*****  2022.07.22 09:30  2022
#
#    month  day   time  cc_score  caddie  course  price  facility  \
# 1      7   23  11:13      10.0      10      10     10        10
# 2      7   23  11:08      10.0      10      10     10        10
# 4      7   22  23:11      10.0      10      10     10        10
# 5      7   22  11:25      10.0      10      10     10        10
# 6      7   22  09:30       3.5       8       2      2         2
#
#                                             contents
# 1                                   페어웨이 그린 베스트 명품구장
# 2  라운딩 체험으로 운동했는데 날씨도 햇빛 없는 날과함께 즐거웠습니다\n모든 좋았으나한...
# 4  아침부터 비가 온 것을 제외하고는 좋았습니다.\n잘 관리된 페어웨이와 그린 그리고 ...
# 5  첫홀은 비가와서 징행할까 말까 했었는데\n그래도 멀리왔는데 치고가자 고 일행이 적극...
# 6  좋은 날 기분 더럽게 다녀왔네요.. 코스관리 개엉망이고 그린은 완전 걸레짝. 카운터...

# %% [markdown]
# ### 사용자 데이터프레임 생성

# %%
# 전처리 후 unique id 개수 확인
data['id'].nunique()
# Out:
# 6111

# %%
# 사용자 일련번호를 부여한 USER DF 생성
data_id = data['id'].sort_values().drop_duplicates().reset_index()
data_id = data_id.rename(columns={'index':'id_num'})
data_id['id_num'] = range(1,len(data_id)+1)
data_id
# Out:
#       id_num            id
# 0          1        002***
# 1          2       003****
# 2          3        007***
# 3          4      007*****
# 4          5    010*******
# ...      ...           ...
# 6106    6107       zzi****
# 6107    6108  zzi*********
# 6108    6109       zzu****
# 6109    6110          zzz*
# 6110    6111         zzz**
#
# [6111 rows x 2 columns]

# %% [markdown]
# ### 골프장 데이터프레임 생성

# %%
# 골프장 DF 생성
data_cc = data['cc_name'].sort_values().drop_duplicates().reset_index()
data_cc = data_cc.rename(columns={'index':'cc_num'})
data_cc['cc_num'] = range(1,len(data_cc)+1)
data_cc
# Out:
#      cc_num        cc_name
# 0         1           360도
# 1         2             88
# 2         3  H1 CLUB(구 덕평)
# 3         4          XGOLF
# 4         5     XGOLF(테스트)
# ..      ...            ...
# 134     135       한양파인(P9)
# 135     136             한원
# 136     137           해솔리아
# 137     138         화성(P9)
# 138     139           화성상록
#
# [139 rows x 2 columns]

# %%
data_cc.head(10)
# Out:
#    cc_num        cc_name
# 0       1           360도
# 1       2             88
# 2       3  H1 CLUB(구 덕평)
# 3       4          XGOLF
# 4       5     XGOLF(테스트)
# 5       6         가산노블리스
# 6       7         가평베네스트
# 7       8          강남300
# 8       9    고양컨트리클럽(P9)
# 9      10            곤지암

# %%
# XGOLF는 골프장이 아닌 테스트용 인것으로 보임
data_test = data[(data['cc_name'].str.contains('XGOLF'))]
data_test.shape
# Out:
# (27, 14)

# %%
# 추가 전처리 필요... XGOLF 삭제하여 Base DF 변경 -> 행 개수: 24794 - 27 = 24767
data = data[~(data['cc_name'].str.contains('XGOLF'))]
data.shape
# Out:
# (24767, 14)

# %%
# Base DF 변경에 따른 USER DF 재생성
data_id = data['id'].sort_values().drop_duplicates().reset_index()
data_id = data_id.rename(columns={'index':'id_num'})
data_id['id_num'] = range(1,len(data_id)+1)
data_id
# Out:
#       id_num            id
# 0          1        002***
# 1          2       003****
# 2          3        007***
# 3          4      007*****
# 4          5    010*******
# ...      ...           ...
# 6103    6104       zzi****
# 6104    6105  zzi*********
# 6105    6106       zzu****
# 6106    6107          zzz*
# 6107    6108         zzz**
#
# [6108 rows x 2 columns]

# %%
# Base DF 변경에 따른 골프장 DF 재생성
data_cc = data['cc_name'].sort_values().drop_duplicates().reset_index()
data_cc = data_cc.rename(columns={'index':'cc_num'})
data_cc['cc_num'] = range(1,len(data_cc)+1)
data_cc
# Out:
#      cc_num        cc_name
# 0         1           360도
# 1         2             88
# 2         3  H1 CLUB(구 덕평)
# 3         4         가산노블리스
# 4         5         가평베네스트
# ..      ...            ...
# 132     133       한양파인(P9)
# 133     134             한원
# 134     135           해솔리아
# 135     136         화성(P9)
# 136     137           화성상록
#
# [137 rows x 2 columns]

# %%
# id 정보 csv 추출
data_id.to_csv('./data/xgolf_user_completed.csv')

# %%
# 골프장 정보 csv 추출
data_cc.to_csv('./data/xgolf_cc_completed.csv')

# %%
# Base DF에 id_num 및 cc_num 삽입
data = pd.merge(data, data_id, on = 'id', how = 'left')
data = pd.merge(data, data_cc, on = 'cc_name', how = 'left')
data
# Out:
#          cc_name                     title          id          datetime  \
# 0             금강                      굿 금강     yun****  2022.07.23 11:13
# 1      비에이비스타퍼블릭  양프로,티칭프로테스트를 앞둔 예비프로와 함께   Wls******  2022.07.23 11:08
# 2          스카이밸리     재촉만 하지 않았으면 최고였을텐데...      bab***  2022.07.22 23:11
# 3            몽베르                  몽베르라운딩후기   ljk******  2022.07.22 11:25
# 4             썬힐             정말 해도해도 너무하네요    cli*****  2022.07.22 09:30
# ...          ...                       ...         ...               ...
# 24762      스카이밸리             마운틴코스라기에. . .    ana*****  2018.01.01 21:50
# 24763       아일랜드                    아일랜드CC     dda****  2018.01.01 14:58
# 24764         기흥                     눈 속에서      l3l***  2018.01.01 12:13
# 24765         88             2017년 마지막 라운딩  pol*******  2018.01.01 04:17
# 24766        남서울                 눈은 왔었지만,,      msd***  2018.01.01 00:39
#
#        year  month  day   time  cc_score  caddie  course  price  facility  \
# 0      2022      7   23  11:13      10.0      10      10     10        10
# 1      2022      7   23  11:08      10.0      10      10     10        10
# 2      2022      7   22  23:11      10.0      10      10     10        10
# 3      2022      7   22  11:25      10.0      10      10     10        10
# 4      2022      7   22  09:30       3.5       8       2      2         2
# ...     ...    ...  ...    ...       ...     ...     ...    ...       ...
# 24762  2018      1    1  21:50       9.5      10       8     10        10
# 24763  2018      1    1  14:58      10.0      10      10     10        10
# 24764  2018      1    1  12:13       9.5      10      10      8        10
# 24765  2018      1    1  04:17       9.0       8       8     10        10
# 24766  2018      1    1  00:39      10.0      10      10     10        10
#
#                                                 contents  id_num  cc_num
# 0                                       페어웨이 그린 베스트 명품구장    6029      15
# 1      라운딩 체험으로 운동했는데 날씨도 햇빛 없는 날과함께 즐거웠습니다\n모든 좋았으나한...     186      53
# 2      아침부터 비가 온 것을 제외하고는 좋았습니다.\n잘 관리된 페어웨이와 그린 그리고 ...     460      68
# 3      첫홀은 비가와서 징행할까 말까 했었는데\n그래도 멀리왔는데 치고가자 고 일행이 적극...    3498      44
# 4      좋은 날 기분 더럽게 다녀왔네요.. 코스관리 개엉망이고 그린은 완전 걸레짝. 카운터...     887      73
# ...                                                  ...     ...     ...
# 24762  눈이라도 많을까봐 걱정했는데.\n플레이하기에 전혀 지장이 없는\n상태로 코스는 잘 ...     333      68
# 24763                         바람이 좀 춥긴했지만 관리도 잘되있고 좋았습니다    1097      78
# 24764  눈이 오는 바람에 정상적인 라운드를 할 수 없었지만 너무 좋은 멤버들과 캐디 덕분에...    3355      16
# 24765  다행히 날씨가 춥지 않아 즐거운 라운딩이었음.\n11:32 티업. 전반 지나고 그늘...    4386       2
# 24766               잼있는 코스와 친절한 캐디분이 있어서 항상 줄거운 골프장이네요^^    3857      19
#
# [24767 rows x 16 columns]

# %%
# 데이터 병합 확인
print(data['id_num'].isnull().sum(), data['cc_num'].isnull().sum())
# Out:
# 0 0

# %%
# 혹시 모를 중복 확인
data[(data.duplicated())]
# Out:
# Empty DataFrame
# Columns: [cc_name, title, id, datetime, year, month, day, time, cc_score, caddie, course, price, facility, contents, id_num, cc_num]
# Index: []

# %%
# 전처리 끝난 최종 데이터 csv 추출
data.to_csv('./data/xgolf_contents_completed.csv')

# %%
# 카테고리(전체/캐디/코스/가격/시설) 별 평점 데이터프레임 생성 및 csv 추출 - 추후 원활한 분석 작업을 위해
ratings_cc_df = data[['id_num', 'cc_num', 'cc_score', 'cc_name']]
ratings_caddie_df = data[['id_num', 'cc_num', 'caddie', 'cc_name']]
ratings_course_df = data[['id_num', 'cc_num', 'course', 'cc_name']]
ratings_price_df = data[['id_num', 'cc_num', 'price', 'cc_name']]
ratings_facility_df = data[['id_num', 'cc_num', 'facility', 'cc_name']]

ratings_cc_df.to_csv('./data/overall_rating_completed.csv')
ratings_caddie_df.to_csv('./data/caddie_rating_completed.csv')
ratings_course_df.to_csv('./data/course_rating_completed.csv')
ratings_price_df.to_csv('./data/price_rating_completed.csv')
ratings_facility_df.to_csv('./data/facility_rating_completed.csv')
